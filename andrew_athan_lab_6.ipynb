# %%
map_api_key = "AIzaSyB5TpuD5rORDc-XYza4GfPYQRaQspF0jFM"

# %%
import os
import requests
from typing import List, Optional

# %%
def is_location_in_us(location_text: str) -> Optional[bool]:
    """
    Uses the Google Maps Geocoding API to check whether a location
    resolves to a US address. Returns None if no location could be
    resolved (e.g., no location mentioned in the text).
    """

    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location_text, "key": map_api_key}

    try:
        resp = requests.get(url, params=params, timeout=10)
        resp.raise_for_status()
        data = resp.json()

        if data.get("status") != "OK" or not data.get("results"):
            return None

        components = data["results"][0].get("address_components", [])
        for comp in components:
            if "country" in comp.get("types", []):
                return comp.get("short_name") == "US"
        return None

    except (requests.RequestException, ValueError, KeyError, IndexError):
        return None

# %%
def get_lat_lon(city: str) -> Optional[List[float]]:
    """
    Get the latitude and longitude for a given city name using the
    Google Maps Geocoding API.

    Args:
        city (str): Name of the city (e.g., "San Diego", "Paris, France").

    Returns:
        Optional[List[float]]: A two-element list [latitude, longitude]
        if the city is found. Returns None if the city cannot be found,
        the API key is missing, or an error occurs.
    """


    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "address": city,
        "key": map_api_key,
    }

    try:
        resp = requests.get(url, params=params, timeout=10)
        resp.raise_for_status()
        data = resp.json()

        if data.get("status") != "OK" or not data.get("results"):
            return None

        location = data["results"][0]["geometry"]["location"]
        lat = float(location["lat"])
        lon = float(location["lng"])
        return [lat, lon]

    except (requests.RequestException, ValueError, KeyError, IndexError):
        raise

# %%
print(is_location_in_us("San Diego"))
get_lat_lon("San Diego")
# Out:
# True
# [32.715738, -117.1610838]

# %%
import requests
from typing import Optional, List, Dict

def get_extended_weather_forecast(lat: float, lon: float) -> Optional[List[Dict[str, str]]]:
    """
    Fetch the extended weather forecast from the U.S. National Weather Service API
    based on a given latitude and longitude.

    Args:
        lat (float): Latitude of the location (e.g., 38.8977).
        lon (float): Longitude of the location (e.g., -77.0365).

    Returns:
        Optional[List[Dict[str, str]]]: A list of forecast dictionaries
        (each containing keys like "name", "temperature", "temperatureUnit",
        "shortForecast", "detailedForecast", "windSpeed", "windDirection"),
        one per forecast period (e.g., "Tonight", "Wednesday", "Wednesday Night", ...).
        Returns None if data is unavailable or an error occurs.
    """
    headers = {
        # NWS API requires a descriptive User-Agent (app name + contact info)
        "User-Agent": "(weather-app, contact@example.com)",
        "Accept": "application/geo+json",
    }

    try:
        # Step 1: Look up the grid endpoint for this lat/lon
        points_url = f"https://api.weather.gov/points/{lat},{lon}"
        points_resp = requests.get(points_url, headers=headers, timeout=10)
        points_resp.raise_for_status()
        points_data = points_resp.json()

        forecast_url = points_data.get("properties", {}).get("forecast")
        if not forecast_url:
            return None

        # Step 2: Fetch the extended forecast from the grid-specific endpoint
        forecast_resp = requests.get(forecast_url, headers=headers, timeout=10)
        forecast_resp.raise_for_status()
        forecast_data = forecast_resp.json()

        periods = forecast_data.get("properties", {}).get("periods")
        if not periods:
            return None

        # Step 3: Normalize each period into a simple string-keyed dict
        forecasts = []
        for period in periods:
            forecasts.append({
                "name": str(period.get("name", "")),
                "temperature": str(period.get("temperature", "")),
                "temperatureUnit": str(period.get("temperatureUnit", "")),
                "windSpeed": str(period.get("windSpeed", "")),
                "windDirection": str(period.get("windDirection", "")),
                "shortForecast": str(period.get("shortForecast", "")),
                "detailedForecast": str(period.get("detailedForecast", "")),
            })

        return forecasts

    except (requests.RequestException, ValueError, KeyError):
        # Covers network errors, bad JSON, and unexpected response structure
        return None

# %%
if True:
    san_diego_lat = 32.7157
    san_diego_lon = -117.1611

    forecast = get_extended_weather_forecast(san_diego_lat, san_diego_lon)

    if forecast is None:
        print("Failed to fetch forecast (check network/coords/API status).")
    else:
        print(f"Got {len(forecast)} forecast periods for San Diego:\n")
        for period in forecast:
            print(f"{period['name']}: {period['temperature']}°{period['temperatureUnit']}, "
                  f"{period['shortForecast']} "
                  f"(wind {period['windSpeed']} {period['windDirection']})")
            print(f"  {period['detailedForecast']}\n")
# Out:
# Got 14 forecast periods for San Diego:
#
# Today: 89°F, Patchy Fog then Mostly Sunny (wind 0 to 10 mph S)
#   Patchy fog before 11am. Mostly sunny, with a high near 89. South wind 0 to 10 mph.
#
# Tonight: 73°F, Patchy Fog (wind 0 to 5 mph S)
#   Patchy fog after 11pm. Mostly cloudy, with a low around 73. South wind 0 to 5 mph.
#
# Thursday: 88°F, Patchy Fog then Partly Sunny (wind 0 to 10 mph SW)
#   Patchy fog before 11am. Partly sunny, with a high near 88. Southwest wind 0 to 10 mph.
#
# Thursday Night: 73°F, Patchy Fog (wind 0 to 5 mph SW)
#   Patchy fog after 11pm. Mostly cloudy, with a low around 73. Southwest wind 0 to 5 mph.
#
# Friday: 89°F, Patchy Fog then Mostly Sunny (wind 0 to 10 mph SW)
#   Patchy fog before 11am. Mostly sunny, with a high near 89. Southwest wind 0 to 10 mph.
#
# Friday Night: 74°F, Patchy Fog (wind 0 to 5 mph NW)
#   Patchy fog after 11pm. Partly cloudy, with a low around 74.
#
# Saturday: 88°F, Patchy Fog then Sunny (wind 0 to 10 mph NW)
#   Patchy fog before 11am. Sunny, with a high near 88.
#
# Saturday Night: 72°F, Partly Cloudy (wind 0 to 10 mph W)
#   Partly cloudy, with a low around 72.
#
# Sunday: 82°F, Sunny (wind 0 to 10 mph W)
#   Sunny, with a high near 82.
#
# Sunday Night: 69°F, Partly Cloudy (wind 0 to 10 mph W)
#   Partly cloudy, with a low around 69.
#
# Monday: 81°F, Mostly Sunny (wind 0 to 10 mph W)
#   Mostly sunny, with a high near 81.
#
# Monday Night: 69°F, Partly Cloudy (wind 5 to 10 mph NW)
#   Partly cloudy, with a low around 69.
#
# Tuesday: 81°F, Partly Sunny (wind 5 to 10 mph NW)
#   Partly sunny, with a high near 81.
#
# Tuesday Night: 70°F, Mostly Cloudy (wind 5 to 10 mph NW)
#   Mostly cloudy, with a low around 70.

# %%
from typing import Optional
from google.adk.agents.callback_context import CallbackContext
from google.adk.models.llm_request import LlmRequest
from google.adk.models.llm_response import LlmResponse

total_hack = 0

def simple_callback(s):
  def func_(callback_context: CallbackContext, llm_request: LlmRequest, s=s) -> Optional[LlmResponse]:
    try:
      last = llm_request.contents[-1]
      if last.role == "user" and last.parts and last.parts[0].text:
        print(f"\n\n---\n{s}: [{callback_context.agent_name}] USER » {last.parts[0].text.strip()}")
        print(f"\n---END---{s}\n\n")
    except:
      pass
    return None
  return func_


def before_callback(callback_context: CallbackContext, llm_request: LlmRequest) -> Optional[LlmResponse]:
  global total_hack
  if total_hack>len(llm_request.contents):
    total_hack = 0
  for last in llm_request.contents[total_hack:]:
    print(total_hack)
    total_hack += 1
    if last.role == "user" and last.parts and last.parts[0].text:
      print(f"[{callback_context.agent_name}] USER » {last.parts[0].text.strip()}")
      if mod:=moderate(last.parts[0].text):
        return mod
  return None

def moderate(mod:str) -> Optional[LlmResponse]:
  try:
    if 'do not allow this' in mod:
      return LlmResponse(content={
        "role": "model",
        "parts": [{"text": "Message violates our content guidelines."}]})
  except Exception as e:
    raise
  return None

def after_callback(callback_context: CallbackContext, llm_response: LlmResponse) -> Optional[LlmResponse]:
  if llm_response.content and llm_response.content.parts:
    txt = llm_response.content.parts[0].text
    if txt:
      print(f"[{callback_context.agent_name} MODEL » {txt.strip()}")
  return None

# %%
# !pip install google-adk[extensions]
# Out:
# Requirement already satisfied: google-adk[extensions] in /usr/local/lib/python3.12/dist-packages (2.4.0)
# Requirement already satisfied: aiosqlite>=0.21 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.22.1)
# Requirement already satisfied: authlib<2,>=1.6.6 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.7.2)
# Requirement already satisfied: click<9,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (8.4.2)
# Requirement already satisfied: fastapi<1,>=0.133 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.139.0)
# Requirement already satisfied: google-auth>=2.47 in /usr/local/lib/python3.12/dist-packages (from google-auth[pyopenssl]>=2.47->google-adk[extensions]) (2.49.0)
# Requirement already satisfied: google-genai<3,>=2.9 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.11.0)
# Requirement already satisfied: graphviz<1,>=0.20.2 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.21)
# Requirement already satisfied: httpx<1,>=0.27 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.28.1)
# Requirement already satisfied: jsonschema<5,>=4.23 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.26.0)
# Requirement already satisfied: opentelemetry-api<=1.42.1,>=1.39 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk<=1.42.1,>=1.39 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.42.1)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (26.2)
# Requirement already satisfied: pydantic<3,>=2.12 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.13.4)
# Requirement already satisfied: python-dotenv<2,>=1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.2.2)
# Requirement already satisfied: python-multipart<1,>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.0.32)
# Requirement already satisfied: pyyaml<7,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (6.0.3)
# Requirement already satisfied: requests<3,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.32.4)
# Requirement already satisfied: starlette<2,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.3.1)
# Requirement already satisfied: tenacity<10,>=9 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.16.0)
# Requirement already satisfied: tzlocal<6,>=5.3 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (5.4.4)
# Requirement already satisfied: uvicorn<1,>=0.34 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.51.0)
# Requirement already satisfied: watchdog<7,>=6 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (6.0.0)
# Requirement already satisfied: websockets<16,>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (15.0.1)
# Requirement already satisfied: anthropic>=0.78 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.0.0)
# Requirement already satisfied: beautifulsoup4>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.13.5)
# Requirement already satisfied: docker>=7 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (7.2.0)
# Requirement already satisfied: google-cloud-firestore<3,>=2.11 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.27.0)
# Requirement already satisfied: k8s-agent-sandbox>=0.1.1.post3 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.5.6)
# Requirement already satisfied: kubernetes>=29 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (36.0.3)
# Requirement already satisfied: langgraph<0.4.8,>=0.2.60 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.4.7)
# Requirement already satisfied: litellm>=1.84 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.98.0)
# Requirement already satisfied: llama-index-embeddings-google-genai>=0.3 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.5.1)
# Requirement already satisfied: llama-index-readers-file>=0.4 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.6.0)
# Requirement already satisfied: lxml>=5.3 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (6.1.1)
# Requirement already satisfied: openai<3,>=2.20 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.45.0)
# Requirement already satisfied: pypika>=0.50 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.51.1)
# Requirement already satisfied: toolbox-adk<2,>=1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.78->google-adk[extensions]) (4.14.2)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.78->google-adk[extensions]) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.78->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.78->google-adk[extensions]) (0.16.0)
# Requirement already satisfied: sniffio<2,>=1 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.78->google-adk[extensions]) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2,>=1.6.6->google-adk[extensions]) (49.0.0)
# Requirement already satisfied: joserfc>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from authlib<2,>=1.6.6->google-adk[extensions]) (1.7.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=3.2.2->google-adk[extensions]) (2.8.4)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker>=7->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1,>=0.133->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1,>=0.133->google-adk[extensions]) (0.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.47->google-auth[pyopenssl]>=2.47->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.47->google-auth[pyopenssl]>=2.47->google-adk[extensions]) (4.9.1)
# Requirement already satisfied: pyopenssl>=20.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[pyopenssl]>=2.47->google-adk[extensions]) (26.3.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-firestore<3,>=2.11->google-adk[extensions]) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-firestore<3,>=2.11->google-adk[extensions]) (2.6.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-firestore<3,>=2.11->google-adk[extensions]) (1.83.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-firestore<3,>=2.11->google-adk[extensions]) (1.28.1)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-cloud-firestore<3,>=2.11->google-adk[extensions]) (6.33.6)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3,>=2.9->google-adk[extensions]) (1.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.27->google-adk[extensions]) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.27->google-adk[extensions]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.27->google-adk[extensions]) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.27->google-adk[extensions]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5,>=4.23->google-adk[extensions]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5,>=4.23->google-adk[extensions]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5,>=4.23->google-adk[extensions]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5,>=4.23->google-adk[extensions]) (2026.6.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from k8s-agent-sandbox>=0.1.1.post3->google-adk[extensions]) (0.25.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29->google-adk[extensions]) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29->google-adk[extensions]) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29->google-adk[extensions]) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29->google-adk[extensions]) (0.11)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29->google-adk[extensions]) (3.14.3)
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.4.9)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.1.0)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.8.1)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (0.14.0)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (0.13.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (8.9.0)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (0.22.2)
# Requirement already satisfied: jinja2<4.0,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (3.1.6)
# Requirement already satisfied: pydantic-settings<3.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (2.15.0)
# Requirement already satisfied: boto3<2.0,>=1.43.1 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.84->google-adk[extensions]) (1.43.80)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (0.14.24)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4->google-adk[extensions]) (0.7.1)
# Requirement already satisfied: pandas<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4->google-adk[extensions]) (2.2.2)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4->google-adk[extensions]) (6.16.2)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4->google-adk[extensions]) (0.0.26)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=2.20->google-adk[extensions]) (4.67.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<=1.42.1,>=1.39->google-adk[extensions]) (0.63b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.12->google-adk[extensions]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.12->google-adk[extensions]) (2.46.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.4->google-adk[extensions]) (3.4.9)
# Requirement already satisfied: toolbox-core==1.3.0 in /usr/local/lib/python3.12/dist-packages (from toolbox-adk<2,>=1->google-adk[extensions]) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from toolbox-adk<2,>=1->google-adk[extensions]) (1.4.0)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.15 in /usr/local/lib/python3.12/dist-packages (from toolbox-core==1.3.0->toolbox-adk<2,>=1->google-adk[extensions]) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=29->google-adk[extensions]) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=29->google-adk[extensions]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=29->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=29->google-adk[extensions]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=29->google-adk[extensions]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=29->google-adk[extensions]) (1.24.2)
# Requirement already satisfied: botocore<1.44.0,>=1.43.80 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.43.1->litellm>=1.84->google-adk[extensions]) (1.43.80)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.43.1->litellm>=1.84->google-adk[extensions]) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.43.1->litellm>=1.84->google-adk[extensions]) (0.19.2)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2,>=1.6.6->google-adk[extensions]) (2.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-firestore<3,>=2.11->google-adk[extensions]) (1.75.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-firestore<3,>=2.11->google-adk[extensions]) (1.83.0)
# Requirement already satisfied: httpcore2==2.5.0 in /usr/local/lib/python3.12/dist-packages (from httpx2<3,>=2.0.0->anthropic>=0.78->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.12/dist-packages (from httpx2<3,>=2.0.0->anthropic>=0.78->google-adk[extensions]) (0.10.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm>=1.84->google-adk[extensions]) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0,>=3.1.6->litellm>=1.84->google-adk[extensions]) (3.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.10.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.17.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint>=2.0.26->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk>=0.1.42->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.11.9)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (0.6.7)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2025.3.0)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.23.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (3.10.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (4.10.0)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (84.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.0.51)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.3.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file>=0.4->google-adk[extensions]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file>=0.4->google-adk[extensions]) (2026.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47->google-auth[pyopenssl]>=2.47->google-adk[extensions]) (0.6.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=29->google-adk[extensions]) (3.3.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0,>=0.8.0->litellm>=1.84->google-adk[extensions]) (2025.11.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1.0,>=0.21.0->litellm>=1.84->google-adk[extensions]) (1.23.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography->authlib<2,>=1.6.6->google-adk[extensions]) (3.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.84->google-adk[extensions]) (3.29.7)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.84->google-adk[extensions]) (1.5.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.25.0)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (0.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (1.5.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (3.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (3.26.2)
# Requirement already satisfied: griffecli==2.2.0 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.2.0)
# Requirement already satisfied: griffelib==2.2.0 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (2.2.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffecli==2.2.0->griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3->google-adk[extensions]) (0.4.6)

# %%
from google.adk.agents import Agent,SequentialAgent
from google.adk.models.lite_llm import LiteLlm
from google.adk.agents import LlmAgent
from google.adk.tools import agent_tool
from google.adk.agents import LlmAgent
from google.adk.tools import google_search

model="gemini-2.5-flash"

search_agent = LlmAgent(
  name="google_search_agent",
  model=model,
  description="Provides Google Search Results.",
  instruction="If the user is asking a question that can be answered by google search, use this tool to provide results.",
  tools=[google_search]
)

weather_agent = Agent(
  name="Andrew3",
  #model=LiteLlm(model="openai/gpt-4o"), <--- I do not have credentials to run this
  model=model,
  description=(
    "Weather agent."
  ),
  instruction="You are a weather agent able to get weather forecasts from a city or lat, long. One of your tools allows you to check if a location is in the US, use it to ensure a location is in the US. If it is not, refuse to respond."  ,
  tools=[get_extended_weather_forecast, get_lat_lon,is_location_in_us],
  before_model_callback=before_callback,
  after_model_callback=after_callback
)

critique = Agent(
  name="Andrew4",
  model=model,
  description="Critique agent.",
  before_model_callback=simple_callback("critique"),
  instruction="List some ways to refine the city description and list of things to do. Be specific",
)

refine = Agent(
  name="Andrew5",
  model=model,
  description="Refinement agent.",
  before_model_callback=simple_callback("refine"),
  instruction="Implement the suggestions listed by the critique agent.",
)

critique_refine = SequentialAgent(
  name="critique_refine",
  description="Critiques then refines raw text.",
  sub_agents=[
    critique,
    refine,
  ],
)

root_agent = Agent(
  name="greeter",
  model=model,
  description="Greeter.",
  instruction=
  """
  Imagine a nice day in the requested city and describe it. Use the weather agent to describe the city according to the weather. Use the search agent to find things to do in the city. Use your subagents to critique and refine your response."
  """,
  tools=[agent_tool.AgentTool(agent=weather_agent),agent_tool.AgentTool(agent=search_agent)],
  sub_agents=[critique_refine],
)
# Out:
# /tmp/ipykernel_1675/1228037598.py:47: DeprecationWarning: SequentialAgent is deprecated in favor of Workflow and will be removed in a future version. Workflow cannot yet be used as an LlmAgent sub-agent.
#   critique_refine = SequentialAgent(

# %%
from vertexai.preview import reasoning_engines
app = reasoning_engines.AdkApp(
agent= root_agent,
)

# %%
from IPython.display import Markdown, display
user_id="test-user-id-5"

session = app.create_session(user_id=user_id)

def call(message:str):
  print("\n\n\n")

  for event in app.stream_query(user_id=user_id,session_id=session['id'],
                                message=message):
    try:
      for part in event['content']['parts']:
        print(part['text'])
    except:
      pass

call("tell me about Chicago")
# Out:
# /usr/local/lib/python3.12/dist-packages/vertexai/preview/reasoning_engines/templates/adk.py:966: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   self._tmpl_attrs["credential_service"] = InMemoryCredentialService()
# /usr/local/lib/python3.12/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# /usr/local/lib/python3.12/dist-packages/google/adk/tools/function_tool.py:95: UserWarning: [EXPERIMENTAL] feature FeatureName.JSON_SCHEMA_FOR_FUNC_DECL is enabled.
#   build_function_declaration(
# 0
# [Andrew3] USER » weather in Chicago
# 1
# 2
# 3
# 4
# 5
# 6
# [Andrew3 MODEL » Here's the extended weather forecast for Chicago:
#
# **Today:** A slight chance of showers and thunderstorms after 3pm. Mostly sunny. High near 84°F, with temperatures falling to around 82°F in the afternoon. West southwest wind around 15 mph, with gusts as high as 25 mph. Chance of precipitation is 20%.
#
# **Tonight:** A slight chance of showers and thunderstorms before 7pm. Mostly clear, with a low around 67°F. West northwest wind 5 to 10 mph, with gusts as high as 20 mph. Chance of precipitation is 20%.
#
# **Thursday:** Sunny, with a high near 76°F. North wind 5 to 10 mph.
#
# **Thursday Night:** Mostly clear, with a low around 65°F. Northeast wind 0 to 10 mph.
#
# **Friday:** Sunny, with a high near 76°F. East northeast wind around 5 mph.
#
# **Friday Night:** Partly cloudy, with a low around 64°F.
#
# **Saturday:** Mostly sunny, with a high near 81°F.
#
# **Saturday Night:** Mostly cloudy, with a low around 69°F.
#
# **Sunday:** Partly sunny, with a high near 86°F.
#
# **Sunday Night:** A chance of rain showers after 1am. Partly cloudy, with a low around 73°F.
#
# **Monday:** A chance of rain showers before 7am, then a slight chance of showers and thunderstorms between 7am and 1pm. Partly sunny, with a high near 86°F.
#
# **Monday Night:** A chance of showers and thunderstorms after 1am. Mostly cloudy, with a low around 73°F.
#
# **Tuesday:** A chance of showers and thunderstorms before 1pm, then a slight chance of showers and thunderstorms. Partly sunny, with a high near 83°F.
#
# **Tuesday Night:** A slight chance of showers and thunderstorms. Partly cloudy, with a low around 71°F.
# Imagine a beautiful day in Chicago! The sun is mostly out, with a high near 84°F, though temperatures might dip slightly to 82°F in the afternoon. There's a west southwest wind blowing around 15 mph, with gusts up to 25 mph, making for a refreshing breeze as you explore the city. There's only a slight chance of showers and thunderstorms after 3 pm, so it's mostly clear for your adventures.
#
# With such pleasant weather, you could start your day with a stroll through Millennium Park, admiring the iconic "Cloud Gate" (The Bean) and enjoying its reflections of the vibrant city skyline. The breeze would be perfect for a leisurely walk along the Chicago Riverwalk, perhaps even taking an Architecture River Cruise to marvel at the city's renowned buildings from a unique perspective.
#
# For lunch, grab some classic Chicago-style pizza, and then head over to Navy Pier to enjoy the lively atmosphere and perhaps a ride on the Centennial Ferris Wheel. If you're looking for some culture, the Art Institute of Chicago or the Field Museum of Natural History would be excellent choices, offering world-class exhibits to explore.
#
# As the evening approaches, the slight chance of showers passes before 7 pm, leaving a mostly clear sky with a low around 67°F. This would be a wonderful time to enjoy dinner at one of the many fantastic restaurants on The Magnificent Mile, or perhaps catch a show at the Second City Comedy Club. No matter how you choose to spend your day, Chicago offers an unforgettable experience!

# %%
# !gcloud storage buckets create gs://qwiklabs-gcp-03-a09a00ad9f5f-staging   --project=qwiklabs-gcp-03-a09a00ad9f5f   --location=us-central1
# Out:
# Creating gs://qwiklabs-gcp-03-a09a00ad9f5f-staging/...

# %%
# !gcloud storage buckets list --project=qwiklabs-gcp-03-a09a00ad9f5f
# Out:
# ---
# acl:
# - entity: project-owners-571408851685
#   projectTeam:
#     projectNumber: '571408851685'
#     team: owners
#   role: OWNER
# - entity: project-editors-571408851685
#   projectTeam:
#     projectNumber: '571408851685'
#     team: editors
#   role: OWNER
# - entity: project-viewers-571408851685
#   projectTeam:
#     projectNumber: '571408851685'
#     team: viewers
#   role: READER
# creation_time: 2026-08-26T16:37:29+0000
# default_acl:
# - entity: project-owners-571408851685
#   projectTeam:
#     projectNumber: '571408851685'
#     team: owners
#   role: OWNER
# - entity: project-editors-571408851685
#   projectTeam:
#     projectNumber: '571408851685'
#     team: editors
#   role: OWNER
# - entity: project-viewers-571408851685
#   projectTeam:
#     projectNumber: '571408851685'
#     team: viewers
#   role: READER
# default_storage_class: STANDARD
# generation: 1787762249381353823
# location: US-CENTRAL1
# location_type: region
# metageneration: 1
# name: qwiklabs-gcp-03-a09a00ad9f5f-staging
# public_access_prevention: inherited
# soft_delete_policy:
#   effectiveTime: '2026-08-26T16:37:29.494000+00:00'
#   retentionDurationSeconds: '604800'
# storage_url: gs://qwiklabs-gcp-03-a09a00ad9f5f-staging/
# uniform_bucket_level_access: false
# update_time: 2026-08-26T16:37:29+0000

# %%
import vertexai

#gcloud storage buckets create gs://qwiklabs-gcp-03-a09a00ad9f5f-staging   --project=qwiklabs-gcp-03-a09a00ad9f5f   --location=us-central1
#Creating gs://qwiklabs-gcp-03-a09a00ad9f5f-staging/...
#$ gcloud storage buckets list --project=qwiklabs-gcp-03-a09a00ad9f5f
...

vertexai.init(
project="qwiklabs-gcp-03-a09a00ad9f5f",
location="us-central1",
staging_bucket="gs://qwiklabs-gcp-03-a09a00ad9f5f-staging",
)

# %%
from vertexai import agent_engines
remote_agent = agent_engines.create(
app,
requirements=["google-cloud-aiplatform[agent_engines,adk]"],
)
# Out:
# INFO:vertexai.agent_engines:Identified the following requirements: {'pydantic': '2.13.4', 'google-cloud-aiplatform': '1.163.0', 'cloudpickle': '3.1.2'}
# WARNING:vertexai.agent_engines:The following requirements are missing: {'pydantic', 'cloudpickle'}
# INFO:vertexai.agent_engines:The following requirements are appended: {'pydantic==2.13.4', 'cloudpickle==3.1.2'}
# INFO:vertexai.agent_engines:The final list of requirements: ['google-cloud-aiplatform[agent_engines,adk]', 'pydantic==2.13.4', 'cloudpickle==3.1.2']
# INFO:vertexai.agent_engines:Using bucket qwiklabs-gcp-03-a09a00ad9f5f-staging
# INFO:vertexai.agent_engines:Wrote to gs://qwiklabs-gcp-03-a09a00ad9f5f-staging/agent_engine/agent_engine.pkl
# INFO:vertexai.agent_engines:Writing to gs://qwiklabs-gcp-03-a09a00ad9f5f-staging/agent_engine/requirements.txt
# INFO:vertexai.agent_engines:Creating in-memory tarfile of extra_packages
# INFO:vertexai.agent_engines:Writing to gs://qwiklabs-gcp-03-a09a00ad9f5f-staging/agent_engine/dependencies.tar.gz
# WARNING:vertexai.agent_engines:Bidi stream API mode is not supported yet in Vertex SDK, please use the GenAI SDK instead. Skipping method bidi_stream_query.
# INFO:vertexai.agent_engines:Creating AgentEngine
# INFO:vertexai.agent_engines:Create AgentEngine backing LRO: projects/571408851685/locations/us-central1/reasoningEngines/1587876759682940928/operations/233131121179623424
# INFO:vertexai.agent_engines:View progress and logs at https://console.cloud.google.com/logs/query?project=qwiklabs-gcp-03-a09a00ad9f5f
# INFO:vertexai.agent_engines:AgentEngine created. Resource name: projects/571408851685/locations/us-central1/reasoningEngines/1587876759682940928
# INFO:vertexai.agent_engines:To use this AgentEngine in another session:
# INFO:vertexai.agent_engines:agent_engine = vertexai.agent_engines.get('projects/571408851685/locations/us-central1/reasoningEngines/1587876759682940928')

# %%
for event in remote_agent.stream_query(user_id="agent-engine-test-user",message="Do your thing for San Francisco."):
  print(event)
# Out:
# {'error_code': 'TypeError', 'error_message': "'NoneType' object is not subscriptable", 'invocation_id': 'e-ee3fa534-523b-4818-a0d2-5558b7fdc66b', 'author': 'greeter', 'actions': {'state_delta': {}, 'artifact_delta': {}, 'requested_auth_configs': {}, 'requested_tool_confirmations': {}}, 'node_info': {'path': 'greeter@1'}, 'id': '3eae1721-9428-4227-9733-78b1a5f96933', 'timestamp': 1787763386.1370485}
